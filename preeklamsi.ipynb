# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/Data Mining/Pertemuan 1 Kasus Preeklamsi/dataKasus-1.xlsx'

# %%
df = pd.read_excel(file_path)

# %%
df.head()
# Out:
#    NO    NAMA   USIA  PARITAS JARAK KELAHIRAN RIW HIPERTENSI RIW PE OBESITAS  \
# 0   1  NAMA 1  23 TH        3       < 2 tahun          Tidak  Tidak    Tidak
# 1   2  NAMA 2  29 TH        2       < 2 tahun          Tidak    PEB    Tidak
# 2   3  NAMA 3  20 TH        1    anak pertama          Tidak  Tidak    Tidak
# 3   4  NAMA 4  18 TH        1    anak pertama          Tidak  Tidak    Tidak
# 4   5  NAMA 5  34 TH        3      > 2 tahun           Tidak  Tidak    Tidak
#
#   RIW DM RIW HIPERTENSI/PE DALAM KELUARGA SOSEK RENDAH PE/Non PE Unnamed: 12
# 0     Ya                            Tidak         >UMR    Non PE         NaN
# 1  Tidak                              Ada         >UMR        PE         NaN
# 2  Tidak                            Tidak         >UMR    Non PE         NaN
# 3  Tidak                            Tidak         >UMR    Non PE         NaN
# 4  Tidak                            Tidak         >UMR    Non PE         NaN

# %%
# df.columns = df.columns.str.strip().str.replace(' ', '_').str.upper()
print(df.shape)
print(df.info())
# Out:
# (561, 13)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   NO                                561 non-null    int64
#  1   NAMA                              561 non-null    object
#  2   USIA                              558 non-null    object
#  3   PARITAS                           561 non-null    int64
#  4   JARAK KELAHIRAN                   554 non-null    object
#  5   RIW HIPERTENSI                    561 non-null    object
#  6   RIW PE                            561 non-null    object
#  7   OBESITAS                          561 non-null    object
#  8   RIW DM                            561 non-null    object
#  9   RIW HIPERTENSI/PE DALAM KELUARGA  561 non-null    object
#  10  SOSEK RENDAH                      561 non-null    object
#  11  PE/Non PE                         561 non-null    object
#  12  Unnamed: 12                       11 non-null     object
# dtypes: int64(2), object(11)
# memory usage: 57.1+ KB
# None

# %%
df.drop("NO", axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   NAMA                              561 non-null    object
#  1   USIA                              558 non-null    object
#  2   PARITAS                           561 non-null    int64
#  3   JARAK KELAHIRAN                   554 non-null    object
#  4   RIW HIPERTENSI                    561 non-null    object
#  5   RIW PE                            561 non-null    object
#  6   OBESITAS                          561 non-null    object
#  7   RIW DM                            561 non-null    object
#  8   RIW HIPERTENSI/PE DALAM KELUARGA  561 non-null    object
#  9   SOSEK RENDAH                      561 non-null    object
#  10  PE/Non PE                         561 non-null    object
#  11  Unnamed: 12                       11 non-null     object
# dtypes: int64(1), object(11)
# memory usage: 52.7+ KB

# %%
df.drop("Unnamed: 12", axis=1, inplace=True)

# %%
print(df.shape)
df.info()
# menghapus NO dan Unnamed:_12
# Out:
# (561, 11)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   NAMA                              561 non-null    object
#  1   USIA                              558 non-null    object
#  2   PARITAS                           561 non-null    int64
#  3   JARAK KELAHIRAN                   554 non-null    object
#  4   RIW HIPERTENSI                    561 non-null    object
#  5   RIW PE                            561 non-null    object
#  6   OBESITAS                          561 non-null    object
#  7   RIW DM                            561 non-null    object
#  8   RIW HIPERTENSI/PE DALAM KELUARGA  561 non-null    object
#  9   SOSEK RENDAH                      561 non-null    object
#  10  PE/Non PE                         561 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 48.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#      NAMA   USIA  PARITAS JARAK KELAHIRAN RIW HIPERTENSI RIW PE OBESITAS  \
# 0  NAMA 1  23 TH        3       < 2 tahun          Tidak  Tidak    Tidak
# 1  NAMA 2  29 TH        2       < 2 tahun          Tidak    PEB    Tidak
# 2  NAMA 3  20 TH        1    anak pertama          Tidak  Tidak    Tidak
# 3  NAMA 4  18 TH        1    anak pertama          Tidak  Tidak    Tidak
# 4  NAMA 5  34 TH        3      > 2 tahun           Tidak  Tidak    Tidak
#
#   RIW DM RIW HIPERTENSI/PE DALAM KELUARGA SOSEK RENDAH PE/Non PE
# 0     Ya                            Tidak         >UMR    Non PE
# 1  Tidak                              Ada         >UMR        PE
# 2  Tidak                            Tidak         >UMR    Non PE
# 3  Tidak                            Tidak         >UMR    Non PE
# 4  Tidak                            Tidak         >UMR    Non PE

# %%
df['USIA'] = df['USIA'].str.replace(' TH', '', regex=False)

# %%
df.head()
# Out:
#      NAMA USIA  PARITAS JARAK KELAHIRAN RIW HIPERTENSI RIW PE OBESITAS RIW DM  \
# 0  NAMA 1   23        3       < 2 tahun          Tidak  Tidak    Tidak     Ya
# 1  NAMA 2   29        2       < 2 tahun          Tidak    PEB    Tidak  Tidak
# 2  NAMA 3   20        1    anak pertama          Tidak  Tidak    Tidak  Tidak
# 3  NAMA 4   18        1    anak pertama          Tidak  Tidak    Tidak  Tidak
# 4  NAMA 5   34        3      > 2 tahun           Tidak  Tidak    Tidak  Tidak
#
#   RIW HIPERTENSI/PE DALAM KELUARGA SOSEK RENDAH PE/Non PE
# 0                            Tidak         >UMR    Non PE
# 1                              Ada         >UMR        PE
# 2                            Tidak         >UMR    Non PE
# 3                            Tidak         >UMR    Non PE
# 4                            Tidak         >UMR    Non PE
